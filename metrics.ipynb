# %% [markdown]
# # Import Library

# %%
import os
from dotenv import load_dotenv
import pandas as pd
from utils import get_metrics, get_big_query_information, load_table_dataframe

# %% [markdown]
# # Load Env Variables

# %%
load_dotenv()

API_VERSION = "v19.0"
ACCESS_TOKEN = os.environ.get("ACCESS_TOKEN", "")
AD_ACCOUNT_ID = os.environ.get("AD_ACCOUNT_ID", "")

# %% [markdown]
# # Get metrics of the API by days

# %%
url = f"https://graph.facebook.com/{API_VERSION}/act_{AD_ACCOUNT_ID}/insights"

params = {
    "fields": "ad_name, adset_name, campaign_name, spend, impressions, reach, cost_per_conversion, frequency, inline_link_clicks, ctr, cpm, cpc, clicks, date_start, ad_id",
    "date_preset": "maximum",
    "time_increment": 1,
    "limit": 100,  # Adjust as needed
    "level": "ad",
}
headers = {"Authorization": f"Bearer {ACCESS_TOKEN}"}

# %% [markdown]
# # Get the data and display it into a table by days

# %%
insights = get_metrics(url, headers, params)

df_day = pd.DataFrame(insights)
df_day.rename(
    columns={
        "ad_name": "Ad_Name",
        "adset_name": "Adset_Name",
        "campaign_name": "Campaign_Name",
        "spend": "Amount_Spend",
        "impressions": "Impressions",
        "reach": "Reach",
        "frequency": "Frequency",
        "ctr": "CTR_all",
        "clicks": "Clicks_all",
        "cpm": "CPM_cost_per_1000_impressions",
        "cpc": "CPC_all",
        "inline_link_clicks": "Link_Clicks",
        "date_start": "Day",
        "ad_id": "Ad_ID",
    },
    inplace=True,
)
# df_day.drop(columns="date_stop", inplace=True)
df_day.head()
df_day
# Out:
#             Ad_Name                 Adset_Name  \
# 0    New Traffic ad         New Traffic ad set
# 1    New Traffic ad  New Traffic ad set – Copy
# 2    New Traffic ad         New Traffic ad set
# 3    New Traffic ad  New Traffic ad set – Copy
# 4    New Traffic ad         New Traffic ad set
# ..              ...                        ...
# 628         in-hand                   BROAD US
# 629   Carousel test                   BROAD EU
# 630             img                   BROAD US
# 631          floral                   BROAD US
# 632          floral                   BROAD EU
#
#                                Campaign_Name Amount_Spend Impressions Reach  \
# 0                      Traffic to Discord #1         0.34         981   980
# 1                      Traffic to Discord #1         0.18         415   414
# 2                      Traffic to Discord #1         1.66        4660  4655
# 3                      Traffic to Discord #1         1.57        3864  3559
# 4                      Traffic to Discord #1         0.98        2962  2957
# ..                                       ...          ...         ...   ...
# 628   [TD] ALC+ (Lead Generation - US)- CORE        14.87         458   442
# 629  [TD] ALC+ (Lead Generation - EU) - CORE         6.65        2100  2032
# 630   [TD] ALC+ (Lead Generation - US)- CORE         0.04           2     2
# 631   [TD] ALC+ (Lead Generation - US)- CORE          0.5          22    22
# 632  [TD] ALC+ (Lead Generation - EU) - CORE         1.63         357   304
#
#     Frequency   CTR_all CPM_cost_per_1000_impressions   CPC_all Clicks_all  \
# 0     1.00102  0.101937                      0.346585      0.34          1
# 1    1.002415  0.240964                      0.433735      0.18          1
# 2    1.001074  0.042918                      0.356223      0.83          2
# 3    1.085698  0.439959                      0.406315  0.092353         17
# 4    1.001691  0.101283                      0.330858  0.326667          3
# ..        ...       ...                           ...       ...        ...
# 628  1.036199  14.19214                     32.467249  0.228769         65
# 629  1.033465         4                      3.166667  0.079167         84
# 630         1         0                            20       NaN          0
# 631         1  9.090909                     22.727273      0.25          2
# 632  1.174342  6.722689                      4.565826  0.067917         24
#
#             Day               Ad_ID   date_stop Link_Clicks
# 0    2023-01-18   23853071466000019  2023-01-18         NaN
# 1    2023-01-18   23853072122590019  2023-01-18           1
# 2    2023-01-19   23853071466000019  2023-01-19           1
# 3    2023-01-19   23853072122590019  2023-01-19          11
# 4    2023-01-20   23853071466000019  2023-01-20           1
# ..          ...                 ...         ...         ...
# 628  2024-05-16  120211169465330020  2024-05-16          34
# 629  2024-05-16  120211262671400020  2024-05-16          57
# 630  2024-05-16  120211393867220020  2024-05-16         NaN
# 631  2024-05-16  120211767697130020  2024-05-16           2
# 632  2024-05-16  120211767777450020  2024-05-16          14
#
# [633 rows x 15 columns]

# %% [markdown]
# # Get metrics of the API by months

# %%
url = f"https://graph.facebook.com/{API_VERSION}/act_{AD_ACCOUNT_ID}/insights"

params = {
    "fields": "ad_name, adset_name, campaign_name, spend, impressions, reach, cost_per_conversion, frequency, inline_link_clicks, ctr, cpm, cpc, clicks, date_start, date_stop, ad_id",
    "time_increment": "monthly",
    "date_preset": "maximum",
    "limit": 100,  # Adjust as needed
    "level": "ad"
}
headers = {"Authorization": f"Bearer {ACCESS_TOKEN}"}

# %% [markdown]
# # Get the metrics and display it into a table by months

# %%
insights = get_metrics(url, headers, params)

df_month = pd.DataFrame(insights)
df_month.rename(columns=
                    {"ad_name": "Ad_Name", "adset_name": "Adset_Name", 
                      "campaign_name": "Campaign_Name", "spend": "Amount_Spend", 
                      "impressions": "Impressions", "reach": "Reach",
                      "frequency": "Frequency", "ctr": "CTR_all",
                      "clicks": "Clicks_all", "cpm": "CPM_cost_per_1000_impressions",
                      "cpc": "CPC_All", "inline_link_clicks": "Link_Clicks",
                      "ad_id": "Ad_ID"
                    },
                 inplace=True
                )
df_month["Month"] = df_month["date_start"] + " - " + df_month["date_stop"]
df_month.drop(columns=["date_stop", "date_start"], inplace=True)

df_month.head()
df_month
# Out:
#                                               Ad_Name  \
# 0                                      New Traffic ad
# 1                                      New Traffic ad
# 2                          Awareness - Europe - Image
# 3                       Awareness - Europe - Carousel
# 4                          Awareness - Europe - Image
# 5     Awareness - Europe - Video Showcasing PUFF Haze
# 6                  Awareness Ad - 3D detail animation
# 7                       Awareness - Europe - Carousel
# 8                       Awareness - Europe - Carousel
# 9     Awareness - Europe - Video Showcasing PUFF Haze
# 10                 Awareness Ad - 3D detail animation
# 11                         Awareness - Europe - Image
# 12                         Awareness - Europe - Image
# 13                      Awareness - Europe - Carousel
# 14                         Awareness - Europe - Image
# 15    Awareness - Europe - Video Showcasing PUFF Haze
# 16                 Awareness Ad - 3D detail animation
# 17                      Awareness - Europe - Carousel
# 18                      Awareness - Europe - Carousel
# 19    Awareness - Europe - Video Showcasing PUFF Haze
# 20                 Awareness Ad - 3D detail animation
# 21                         Awareness - Europe - Image
# 22  Instagram post: Experience the ultimate fusion...
# 23                         Awareness - Europe - Image
# 24    Awareness - Europe - Video Showcasing PUFF Haze
# 25                 Awareness Ad - 3D detail animation
# 26                      Awareness - Europe - Carousel
# 27                      Awareness - Europe - Carousel
# 28    Awareness - Europe - Video Showcasing PUFF Haze
# 29                 Awareness Ad - 3D detail animation
# 30                         Awareness - Europe - Image
# 31                                                DCT
# 32                                                DCT
# 33                                                DCT
# 34                                            VIDEO 1
# 35                                     DUNE IG - Copy
# 36                                            VIDEO 1
# 37                                     DUNE IG - Copy
# 38                                               DC_T
# 39                                       water-pebble
# 40                                       water-pebble
# 41                                        Multi-color
# 42                                        Multi-color
# 43                                            VIDEO 1
# 44                                     DUNE IG - Copy
# 45                                     DUNE IG - Copy
# 46                                               DC_T
# 47                                       water-pebble
# 48                                       water-pebble
# 49                                        Multi-color
# 50                                        Multi-color
# 51                                      Carousel test
# 52                                            in-hand
# 53                                            in-hand
# 54                                      Carousel test
# 55                                                img
# 56                                             floral
# 57                                             floral
#
#                                            Adset_Name  \
# 0                                  New Traffic ad set
# 1                           New Traffic ad set – Copy
# 2    Awareness ad set – Farfetch & Highsnobiety - USA
# 3    Awareness ad set – Farfetch & Highsnobiety - USA
# 4   Awareness ad set – Farfetch & Highsnobiety - Asia
# 5   Awareness ad set – Farfetch & Highsnobiety - Asia
# 6   Awareness ad set – Farfetch & Highsnobiety Europe
# 7   Awareness ad set – Farfetch & Highsnobiety - Asia
# 8   Awareness ad set – Farfetch & Highsnobiety Europe
# 9   Awareness ad set – Farfetch & Highsnobiety Europe
# 10  Awareness ad set – Farfetch & Highsnobiety - Asia
# 11  Awareness ad set – Farfetch & Highsnobiety Europe
# 12   Awareness ad set – Farfetch & Highsnobiety - USA
# 13   Awareness ad set – Farfetch & Highsnobiety - USA
# 14  Awareness ad set – Farfetch & Highsnobiety - Asia
# 15  Awareness ad set – Farfetch & Highsnobiety - Asia
# 16  Awareness ad set – Farfetch & Highsnobiety Europe
# 17  Awareness ad set – Farfetch & Highsnobiety - Asia
# 18  Awareness ad set – Farfetch & Highsnobiety Europe
# 19  Awareness ad set – Farfetch & Highsnobiety Europe
# 20  Awareness ad set – Farfetch & Highsnobiety - Asia
# 21  Awareness ad set – Farfetch & Highsnobiety Europe
# 22                                     Instagram Post
# 23  Awareness ad set – Farfetch & Highsnobiety - Asia
# 24  Awareness ad set – Farfetch & Highsnobiety - Asia
# 25  Awareness ad set – Farfetch & Highsnobiety Europe
# 26  Awareness ad set – Farfetch & Highsnobiety - Asia
# 27  Awareness ad set – Farfetch & Highsnobiety Europe
# 28  Awareness ad set – Farfetch & Highsnobiety Europe
# 29  Awareness ad set – Farfetch & Highsnobiety - Asia
# 30  Awareness ad set – Farfetch & Highsnobiety Europe
# 31                                          BROAD USA
# 32                                           BROAD EU
# 33                                       BROAD CANADA
# 34                                           BROAD EU
# 35                                           BROAD EU
# 36                                           BROAD US
# 37                                           BROAD US
# 38                                           BROAD EU
# 39                                           BROAD EU
# 40                                           BROAD US
# 41                                           BROAD EU
# 42                                           BROAD US
# 43                                           BROAD EU
# 44                                           BROAD EU
# 45                                           BROAD US
# 46                                           BROAD EU
# 47                                           BROAD EU
# 48                                           BROAD US
# 49                                           BROAD EU
# 50                                           BROAD US
# 51                                           BROAD US
# 52                                           BROAD US
# 53                                           BROAD EU
# 54                                           BROAD EU
# 55                                           BROAD US
# 56                                           BROAD US
# 57                                           BROAD EU
#
#                                         Campaign_Name Amount_Spend  \
# 0                               Traffic to Discord #1         2.98
# 1                               Traffic to Discord #1         2.97
# 2                                  Awareness campaign            0
# 3                                  Awareness campaign            0
# 4                                  Awareness campaign        66.15
# 5                                  Awareness campaign        66.29
# 6                                  Awareness campaign         1.63
# 7                                  Awareness campaign        67.13
# 8                                  Awareness campaign         0.57
# 9                                  Awareness campaign         0.51
# 10                                 Awareness campaign        38.09
# 11                                 Awareness campaign         0.62
# 12                                 Awareness campaign            0
# 13                                 Awareness campaign            0
# 14                                 Awareness campaign        45.85
# 15                                 Awareness campaign        59.55
# 16                                 Awareness campaign         0.78
# 17                                 Awareness campaign        93.23
# 18                                 Awareness campaign         0.51
# 19                                 Awareness campaign          0.5
# 20                                 Awareness campaign        37.15
# 21                                 Awareness campaign         0.63
# 22  Instagram post: Experience the ultimate fusion...        19.97
# 23                                 Awareness campaign         7.25
# 24                                 Awareness campaign         5.24
# 25                                 Awareness campaign         0.06
# 26                                 Awareness campaign         7.94
# 27                                 Awareness campaign         0.08
# 28                                 Awareness campaign         0.04
# 29                                 Awareness campaign         8.67
# 30                                 Awareness campaign          0.1
# 31                  [TD] ALC+ (Lead Generation - U.S)       750.84
# 32                   [TD] ALC+ (Lead Generation - EU)       712.56
# 33               [TD] ALC+ (Lead Generation - CANADA)       247.27
# 34            [TD] ALC+ (Lead Generation - EU) - CORE        10.82
# 35            [TD] ALC+ (Lead Generation - EU) - CORE       799.12
# 36             [TD] ALC+ (Lead Generation - US)- CORE         9.08
# 37             [TD] ALC+ (Lead Generation - US)- CORE       684.77
# 38                               [TD] ALC+ TESTING EU       528.39
# 39            [TD] ALC+ (Lead Generation - EU) - CORE       430.06
# 40             [TD] ALC+ (Lead Generation - US)- CORE       280.69
# 41            [TD] ALC+ (Lead Generation - EU) - CORE       102.87
# 42             [TD] ALC+ (Lead Generation - US)- CORE        85.17
# 43            [TD] ALC+ (Lead Generation - EU) - CORE         0.63
# 44            [TD] ALC+ (Lead Generation - EU) - CORE       178.55
# 45             [TD] ALC+ (Lead Generation - US)- CORE       225.19
# 46                               [TD] ALC+ TESTING EU       321.73
# 47            [TD] ALC+ (Lead Generation - EU) - CORE        91.93
# 48             [TD] ALC+ (Lead Generation - US)- CORE       168.08
# 49            [TD] ALC+ (Lead Generation - EU) - CORE       823.45
# 50             [TD] ALC+ (Lead Generation - US)- CORE       912.95
# 51             [TD] ALC+ (Lead Generation - US)- CORE        11.76
# 52             [TD] ALC+ (Lead Generation - US)- CORE         26.6
# 53            [TD] ALC+ (Lead Generation - EU) - CORE        22.66
# 54            [TD] ALC+ (Lead Generation - EU) - CORE       224.96
# 55             [TD] ALC+ (Lead Generation - US)- CORE         5.05
# 56             [TD] ALC+ (Lead Generation - US)- CORE         0.39
# 57            [TD] ALC+ (Lead Generation - EU) - CORE         1.36
#
#    Impressions    Reach Frequency Link_Clicks    CTR_all  \
# 0         8603     7779  1.105926           2   0.069743
# 1         7492     6270  1.194896          18   0.373732
# 2           24       24         1         NaN          0
# 3           13       13         1         NaN          0
# 4       762473   731267  1.042674        1006   0.212467
# 5       726060   697089   1.04156        1067   0.241853
# 6        16626    16068  1.034727           5   0.042103
# 7       760512   706826  1.075954         791   0.212488
# 8         6562     6562         1           2   0.091436
# 9         5507     5356  1.028193         NaN   0.036317
# 10      454136   449412  1.010512         815   0.309379
# 11        7432     7354  1.010606           1   0.053821
# 12           9        9         1         NaN          0
# 13           9        9         1         NaN          0
# 14      819260   673922   1.21566         874   0.180041
# 15     1042740   865280   1.20509        1359   0.201297
# 16       10927    10082  1.083813           3   0.045758
# 17     1594254  1250050  1.275352        1196   0.150854
# 18        8714     8038  1.084101           2   0.080331
# 19        7544     6924  1.089544           3   0.039767
# 20      690539   596227  1.158181        1201   0.295856
# 21       10659     9998  1.066113           1   0.028145
# 22      121679    81584  1.491457         442   0.361607
# 23      221548   221548         1         146    0.12187
# 24      155380   154143  1.008025         117   0.124855
# 25         661      658  1.004559         NaN          0
# 26      240604   237956  1.011128         170   0.137155
# 27        1704     1699  1.002943         NaN   0.058685
# 28         783      780  1.003846           1   0.127714
# 29      262801   259461  1.012873         239   0.155631
# 30        4347     4338  1.002075           1   0.046009
# 31       43235    32349  1.336517        2017   7.230253
# 32      128576    96724  1.329308        4131   5.578024
# 33       25633    20382  1.257629         709     5.1106
# 34        1629     1329  1.225734          22   2.639656
# 35      135525   110188  1.229943        4427   5.924368
# 36         263      215  1.223256          13  11.406844
# 37       33244    27708  1.199798        1900     9.5897
# 38      110291    68692  1.605587        2733   4.432819
# 39       36581    26962  1.356761        1426   8.507149
# 40        7346     5802  1.266115         563  19.343861
# 41       27396    23637   1.15903         661   3.985983
# 42        7235     6518  1.110003         449   9.053214
# 43          93       75      1.24           2   4.301075
# 44       55277    46760  1.182143        1755    4.67283
# 45       12636    11473  1.101368         763   9.583729
# 46      111887    67803  1.650178        2693   3.563417
# 47       17376    13007  1.335896         556   5.835635
# 48        6848     5518  1.241029         415  11.419393
# 49      333675   227194  1.468679        8530   4.084214
# 50       82093    59820  1.372334        3779   6.918982
# 51         809      718  1.126741          60   9.394314
# 52        1526     1355  1.126199          98  10.550459
# 53        8831     7639  1.156041         146   2.740347
# 54       79160    51191  1.546366        1932   3.796109
# 55         504      358  1.407821          14   5.357143
# 56          18       18         1           2  11.111111
# 57         296      285  1.038596          12   6.081081
#
#    CPM_cost_per_1000_impressions   CPC_All Clicks_all               Ad_ID  \
# 0                       0.346391  0.496667          6   23853071466000019
# 1                       0.396423  0.106071         28   23853072122590019
# 2                              0       NaN          0   23853877010110019
# 3                              0       NaN          0   23853877018180019
# 4                       0.086757  0.040833       1620   23853877506500019
# 5                       0.091301  0.037751       1756   23853877506510019
# 6                       0.098039  0.232857          7   23853877506530019
# 7                       0.088269  0.041541       1616   23853877506540019
# 8                       0.086864     0.095          6   23853877506550019
# 9                       0.092609     0.255          2   23853877506560019
# 10                      0.083874   0.02711       1405   23853877506580019
# 11                      0.083423     0.155          4   23853877506590019
# 12                             0       NaN          0   23853877010110019
# 13                             0       NaN          0   23853877018180019
# 14                      0.055965  0.031085       1475   23853877506500019
# 15                      0.057109  0.028371       2099   23853877506510019
# 16                      0.071383     0.156          5   23853877506530019
# 17                      0.058479  0.038765       2405   23853877506540019
# 18                      0.058527  0.072857          7   23853877506550019
# 19                      0.066278  0.166667          3   23853877506560019
# 20                      0.053799  0.018184       2043   23853877506580019
# 21                      0.059105      0.21          3   23853877506590019
# 22                       0.16412  0.045386        440   23854149712050019
# 23                      0.032724  0.026852        270   23853877506500019
# 24                      0.033724   0.02701        194   23853877506510019
# 25                      0.090772       NaN          0   23853877506530019
# 26                         0.033  0.024061        330   23853877506540019
# 27                      0.046948      0.08          1   23853877506550019
# 28                      0.051086      0.04          1   23853877506560019
# 29                      0.032991  0.021198        409   23853877506580019
# 30                      0.023004      0.05          2   23853877506590019
# 31                     17.366485  0.240192       3126  120209793696610020
# 32                      5.541936  0.099353       7172  120209796070860020
# 33                      9.646549  0.188756       1310  120209796140270020
# 34                      6.642112  0.251628         43  120210269033140020
# 35                      5.896477  0.099529       8029  120210269903590020
# 36                     34.524715  0.302667         30  120210269966590020
# 37                     20.598303  0.214796       3188  120210269966610020
# 38                      4.790871  0.108077       4889  120210270578840020
# 39                     11.756376  0.138194       3112  120210496312210020
# 40                      38.20991   0.19753       1421  120210616070300020
# 41                      3.754928  0.094203       1092  120210933055030020
# 42                     11.771942  0.130031        655  120210933172180020
# 43                      6.774194    0.1575          4  120210269033140020
# 44                      3.230096  0.069125       2583  120210269903590020
# 45                     17.821304  0.185954       1211  120210269966610020
# 46                       2.87549  0.080695       3987  120210270578840020
# 47                      5.290631  0.090661       1014  120210496312210020
# 48                     24.544393  0.214936        782  120210616070300020
# 49                       2.46782  0.060423      13628  120210933055030020
# 50                     11.120924  0.160731       5680  120210933172180020
# 51                     14.536465  0.154737         76  120211077138770020
# 52                     17.431193  0.165217        161  120211169465330020
# 53                      2.565961  0.093636        242  120211169702620020
# 54                      2.841839  0.074862       3005  120211262671400020
# 55                     10.019841  0.187037         27  120211393867220020
# 56                     21.666667     0.195          2  120211767697130020
# 57                      4.594595  0.075556         18  120211767777450020
#
#                       Month
# 0   2023-01-01 - 2023-01-31
# 1   2023-01-01 - 2023-01-31
# 2   2023-03-01 - 2023-03-31
# 3   2023-03-01 - 2023-03-31
# 4   2023-03-01 - 2023-03-31
# 5   2023-03-01 - 2023-03-31
# 6   2023-03-01 - 2023-03-31
# 7   2023-03-01 - 2023-03-31
# 8   2023-03-01 - 2023-03-31
# 9   2023-03-01 - 2023-03-31
# 10  2023-03-01 - 2023-03-31
# 11  2023-03-01 - 2023-03-31
# 12  2023-04-01 - 2023-04-30
# 13  2023-04-01 - 2023-04-30
# 14  2023-04-01 - 2023-04-30
# 15  2023-04-01 - 2023-04-30
# 16  2023-04-01 - 2023-04-30
# 17  2023-04-01 - 2023-04-30
# 18  2023-04-01 - 2023-04-30
# 19  2023-04-01 - 2023-04-30
# 20  2023-04-01 - 2023-04-30
# 21  2023-04-01 - 2023-04-30
# 22  2023-04-01 - 2023-04-30
# 23  2023-05-01 - 2023-05-31
# 24  2023-05-01 - 2023-05-31
# 25  2023-05-01 - 2023-05-31
# 26  2023-05-01 - 2023-05-31
# 27  2023-05-01 - 2023-05-31
# 28  2023-05-01 - 2023-05-31
# 29  2023-05-01 - 2023-05-31
# 30  2023-05-01 - 2023-05-31
# 31  2024-04-01 - 2024-04-30
# 32  2024-04-01 - 2024-04-30
# 33  2024-04-01 - 2024-04-30
# 34  2024-04-01 - 2024-04-30
# 35  2024-04-01 - 2024-04-30
# 36  2024-04-01 - 2024-04-30
# 37  2024-04-01 - 2024-04-30
# 38  2024-04-01 - 2024-04-30
# 39  2024-04-01 - 2024-04-30
# 40  2024-04-01 - 2024-04-30
# 41  2024-04-01 - 2024-04-30
# 42  2024-04-01 - 2024-04-30
# 43  2024-05-01 - 2024-05-16
# 44  2024-05-01 - 2024-05-16
# 45  2024-05-01 - 2024-05-16
# 46  2024-05-01 - 2024-05-16
# 47  2024-05-01 - 2024-05-16
# 48  2024-05-01 - 2024-05-16
# 49  2024-05-01 - 2024-05-16
# 50  2024-05-01 - 2024-05-16
# 51  2024-05-01 - 2024-05-16
# 52  2024-05-01 - 2024-05-16
# 53  2024-05-01 - 2024-05-16
# 54  2024-05-01 - 2024-05-16
# 55  2024-05-01 - 2024-05-16
# 56  2024-05-01 - 2024-05-16
# 57  2024-05-01 - 2024-05-16

# %% [markdown]
# # Get country of the API by months

# %%
url = f"https://graph.facebook.com/{API_VERSION}/act_{AD_ACCOUNT_ID}/insights"

params = {
    "fields": "ad_name, adset_name, campaign_name, date_start, date_stop, ad_id, spend, impressions, reach, frequency, ctr, clicks, cpm, cpc,  inline_link_clicks",
    "time_increment": "monthly",
    "limit": 100,  # Adjust as needed
    "level": "ad",
    "date_preset": "maximum",
    "breakdowns": ["country"],
}
headers = {"Authorization": f"Bearer {ACCESS_TOKEN}"}

# %% [markdown]
# # Get the country and display it into a table by months

# %%
insights = get_metrics(url, headers, params)

df_country_month = pd.DataFrame(insights)
df_country_month.rename(
    columns={
        "ad_name": "Ad_Name",
        "adset_name": "Adset_Name",
        "campaign_name": "Campaign_Name",
        "country": "Country",
        "ad_id": "Ad_ID",
        "spend": "Amount_Spend",
        "impressions": "Impressions",
        "reach": "Reach",
        "frequency": "Frequency",
        "ctr": "CTR_all",
        "clicks": "Clicks_all",
        "cpm": "CPM_cost_per_1000_impressions",
        "cpc": "CPC_all",
        "inline_link_clicks": "Link_Clicks",
    },
    inplace=True,
)
df_country_month["Month"] = df_country_month["date_start"] + " - " + df_country_month["date_stop"]
df_country_month.drop(columns=["date_start", "date_stop"], inplace=True)
df_country_month
# Out:
#              Ad_Name          Adset_Name  \
# 0     New Traffic ad  New Traffic ad set
# 1     New Traffic ad  New Traffic ad set
# 2     New Traffic ad  New Traffic ad set
# 3     New Traffic ad  New Traffic ad set
# 4     New Traffic ad  New Traffic ad set
# ...              ...                 ...
# 1839          floral            BROAD EU
# 1840          floral            BROAD EU
# 1841          floral            BROAD EU
# 1842          floral            BROAD EU
# 1843          floral            BROAD EU
#
#                                 Campaign_Name               Ad_ID  \
# 0                       Traffic to Discord #1   23853071466000019
# 1                       Traffic to Discord #1   23853071466000019
# 2                       Traffic to Discord #1   23853071466000019
# 3                       Traffic to Discord #1   23853071466000019
# 4                       Traffic to Discord #1   23853071466000019
# ...                                       ...                 ...
# 1839  [TD] ALC+ (Lead Generation - EU) - CORE  120211767777450020
# 1840  [TD] ALC+ (Lead Generation - EU) - CORE  120211767777450020
# 1841  [TD] ALC+ (Lead Generation - EU) - CORE  120211767777450020
# 1842  [TD] ALC+ (Lead Generation - EU) - CORE  120211767777450020
# 1843  [TD] ALC+ (Lead Generation - EU) - CORE  120211767777450020
#
#      Amount_Spend Impressions Reach Frequency   CTR_all Clicks_all  \
# 0            0.01         212   168  1.261905         0          0
# 1            0.51        1004   886  1.133183         0          0
# 2            0.07         125   125         1         0          0
# 3               0           1     0         0         0          0
# 4               0           1     0         0         0          0
# ...           ...         ...   ...       ...       ...        ...
# 1839     0.020145           4     4         1         0          0
# 1840     1.138218          92    83  1.108434  9.782609          9
# 1841     0.352545          70    67  1.044776  5.714286          4
# 1842     0.302182         205   198  1.035354  3.902439          8
# 1843       3.4348         306   279  1.096774   7.51634         23
#
#      CPM_cost_per_1000_impressions Country   CPC_all Link_Clicks  \
# 0                          0.04717      HK       NaN         NaN
# 1                         0.507968      IT       NaN         NaN
# 2                             0.56      JP       NaN         NaN
# 3                                0      LU       NaN         NaN
# 4                                0      NL       NaN         NaN
# ...                            ...     ...       ...         ...
# 1839                      5.036364      SJ       NaN         NaN
# 1840                     12.371937      SE  0.126469           7
# 1841                      5.036364      CH  0.088136           4
# 1842                      1.474058      UA  0.037773           6
# 1843                     11.224837      GB  0.149339          16
#
#                         Month
# 0     2023-01-01 - 2023-01-31
# 1     2023-01-01 - 2023-01-31
# 2     2023-01-01 - 2023-01-31
# 3     2023-01-01 - 2023-01-31
# 4     2023-01-01 - 2023-01-31
# ...                       ...
# 1839  2024-05-01 - 2024-05-17
# 1840  2024-05-01 - 2024-05-17
# 1841  2024-05-01 - 2024-05-17
# 1842  2024-05-01 - 2024-05-17
# 1843  2024-05-01 - 2024-05-17
#
# [1844 rows x 15 columns]

# %% [markdown]
# # Get regions of the API by months

# %%
url = f"https://graph.facebook.com/{API_VERSION}/act_{AD_ACCOUNT_ID}/insights"

params = {
    "fields": "ad_name, adset_name, campaign_name, date_start, date_stop, ad_id, spend, impressions, reach, frequency, ctr, clicks, cpm, cpc,  inline_link_clicks",
    "time_increment": "monthly",
    "limit": 100,  # Adjust as needed
    "level": "ad",
    "date_preset": "maximum",
    "breakdowns": ["region"],
}
headers = {"Authorization": f"Bearer {ACCESS_TOKEN}"}

# %% [markdown]
# # Get the regions and display it into a table by months

# %%
insights = get_metrics(url, headers, params)

df_region_month = pd.DataFrame(insights)
df_region_month.rename(
    columns={
        "ad_name": "Ad_Name",
        "adset_name": "Adset_Name",
        "campaign_name": "Campaign_Name",
        "region": "Region",
        "ad_id": "Ad_ID",
        "spend": "Amount_Spend",
        "impressions": "Impressions",
        "reach": "Reach",
        "frequency": "Frequency",
        "ctr": "CTR_all",
        "clicks": "Clicks_all",
        "cpm": "CPM_cost_per_1000_impressions",
        "cpc": "CPC_all",
        "inline_link_clicks": "Link_Clicks",
    },
    inplace=True,
)
df_region_month["Month"] = df_region_month["date_start"] + " - " + df_region_month["date_stop"]
df_region_month.drop(columns=["date_start", "date_stop"], inplace=True)
df_region_month
# Out:
#               Ad_Name          Adset_Name  \
# 0      New Traffic ad  New Traffic ad set
# 1      New Traffic ad  New Traffic ad set
# 2      New Traffic ad  New Traffic ad set
# 3      New Traffic ad  New Traffic ad set
# 4      New Traffic ad  New Traffic ad set
# ...               ...                 ...
# 22008          floral            BROAD EU
# 22009          floral            BROAD EU
# 22010          floral            BROAD EU
# 22011          floral            BROAD EU
# 22012          floral            BROAD EU
#
#                                  Campaign_Name               Ad_ID  \
# 0                        Traffic to Discord #1   23853071466000019
# 1                        Traffic to Discord #1   23853071466000019
# 2                        Traffic to Discord #1   23853071466000019
# 3                        Traffic to Discord #1   23853071466000019
# 4                        Traffic to Discord #1   23853071466000019
# ...                                        ...                 ...
# 22008  [TD] ALC+ (Lead Generation - EU) - CORE  120211767777450020
# 22009  [TD] ALC+ (Lead Generation - EU) - CORE  120211767777450020
# 22010  [TD] ALC+ (Lead Generation - EU) - CORE  120211767777450020
# 22011  [TD] ALC+ (Lead Generation - EU) - CORE  120211767777450020
# 22012  [TD] ALC+ (Lead Generation - EU) - CORE  120211767777450020
#
#       Amount_Spend Impressions Reach Frequency   CTR_all Clicks_all  \
# 0             0.52        1306  1204  1.084718         0          0
# 1             0.21         582   540  1.077778  0.171821          1
# 2             0.01          36    34  1.058824         0          0
# 3                0           9     8     1.125         0          0
# 4             0.04          55    40     1.375         0          0
# ...            ...         ...   ...       ...       ...        ...
# 22008     0.019155           4     4         1         0          0
# 22009            0           1     1         1         0          0
# 22010            0           3     3         1         0          0
# 22011     0.019155           1     1         1         0          0
# 22012     0.009577           1     0         0         0          0
#
#       CPM_cost_per_1000_impressions               Region CPC_all Link_Clicks  \
# 0                          0.398162             Cataluña     NaN         NaN
# 1                          0.360825                Dubai    0.21           1
# 2                          0.277778   Emirate of Sharjah     NaN         NaN
# 3                                 0              England     NaN         NaN
# 4                          0.727273              Florida     NaN         NaN
# ...                             ...                  ...     ...         ...
# 22008                      4.788732               Zagreb     NaN         NaN
# 22009                             0         Zuid-Holland     NaN         NaN
# 22010                             0        Île-de-France     NaN         NaN
# 22011                      19.15493              Østfold     NaN         NaN
# 22012                      9.577465  Šibenik-Knin County     NaN         NaN
#
#                          Month
# 0      2023-01-01 - 2023-01-31
# 1      2023-01-01 - 2023-01-31
# 2      2023-01-01 - 2023-01-31
# 3      2023-01-01 - 2023-01-31
# 4      2023-01-01 - 2023-01-31
# ...                        ...
# 22008  2024-05-01 - 2024-05-16
# 22009  2024-05-01 - 2024-05-16
# 22010  2024-05-01 - 2024-05-16
# 22011  2024-05-01 - 2024-05-16
# 22012  2024-05-01 - 2024-05-16
#
# [22013 rows x 15 columns]

# %% [markdown]
# # Get env for Google Big Query

# %%
dataset_id = os.environ.get("DATASET_ID", "")
project_id = os.environ.get("PROJECT_ID", "")
credential_file = "ads-managers-420808-0dee56ef52a5.json"

# %% [markdown]
# # Push df_day Dataframe to Google Big Query

# %%
table_id_by_day = get_big_query_information(
    table="all_information_by_day", dataset_id=dataset_id, project_id=project_id
)
print(f"***** NAME OF TABLE IS: {table_id_by_day} *****")

# %%
data_by_day = load_table_dataframe(credential_file, project_id, table_id_by_day, df_day)
data_by_day

# %% [markdown]
# # Push df_month Dataframe to Google Big Query

# %%
table_id_by_month = get_big_query_information(
    table="all_information_by_month", dataset_id=dataset_id, project_id=project_id
)
print(f"***** NAME OF TABLE IS: {table_id_by_month} *****")

# %%
data_by_month = load_table_dataframe(
    credential_file, project_id, table_id_by_month, df_month
)
data_by_month

# %% [markdown]
# # Push df_country_month Dataframe to Google Big Query

# %%
table_id_country_by_month = get_big_query_information(
    table="country_information_by_month", dataset_id=dataset_id, project_id=project_id
)
print(f"***** NAME OF TABLE IS: {table_id_country_by_month} *****")

# %%
data_country_by_month = load_table_dataframe(
    credential_file, project_id, table_id_country_by_month, df_country_month
)
data_country_by_month

# %% [markdown]
# # Push df_region_month Dataframe to Google Big Query

# %%
table_id_region_by_month = get_big_query_information(
    table="region_information_by_month", dataset_id=dataset_id, project_id=project_id
)
print(f"***** NAME OF TABLE IS: {table_id_region_by_month} *****")

# %%
data_region_by_month = load_table_dataframe(
    credential_file, project_id, table_id_region_by_month, df_region_month
)
data_region_by_month
